# %% [markdown]
# IPL projet

# %% [markdown]
# import laberies and datasets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings. filterwarnings('ignore')
df=pd.read_csv('IPL.csv')

# %%
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
df.head(10)
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 5         6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 6         7  March 31,2022                     Brabourne Stadium, Mumbai
# 7         8   April 1,2022                      Wankhede Stadium, Mumbai
# 8         9   April 2,2022            Dr DY Patil Sports Academy, Mumbai
# 9        10   April 2,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
print(f"your rows are {df.shape[0]} and your columns are {df.shape[1]}")
# Out:
# your rows are 74 and your columns are 20

# %% [markdown]
# 1 whict team won most the matches ?

# %%
match_wins = df['match_winner'].value_counts()
match_wins
# Out:
# match_winner
# Gujarat      12
# Rajasthan    10
# Banglore      9
# Lucknow       9
# Punjab        7
# Delhi         7
# Kolkata       6
# Hyderabad     6
# Chennai       4
# Mumbai        4
# Name: count, dtype: int64

# %%
match_wins = df['match_winner'].value_counts()
sns.barplot(y=match_wins.index, x=match_wins.values , palette='viridis')
plt.title("most matches win by team")
# Out:
# Text(0.5, 1.0, 'most matches win by team')

# %% [markdown]
#  Toss decision Trends

# %%
 sns.countplot(x='toss_decision' ,data=df)
plt.title("Toss Descision Plan")
# Out:
# Text(0.5, 1.0, 'Toss Descision Plan')

# %% [markdown]
# 3 Toss Winner VS match Winner

# %% [markdown]
#  perecntage of both toss winner and match winner

# %%
count=df[df['toss_winner']==df['match_winner']] ['match_id'].count()
percentage=(count*100)/df.shape[0]
percentage.round(2)
# Out:
# np.float64(48.65)

# %% [markdown]
# 4 How Do Teams Win(Runs or Wickets)

# %%
sns.countplot(x='won_by', data=df)
plt.title("Won By")
# Out:
# Text(0.5, 1.0, 'Won By')

# %% [markdown]
# KEY PLAYER PERFORMANCE

# %% [markdown]
# 1 Most Player Of The  Match  Award

# %%
count =df['player_of_the_match'].value_counts().head(10)
count
# Out:
# player_of_the_match
# Kuldeep Yadav        4
# Jos Buttler          3
# Wanindu Hasaranga    2
# Umesh Yadav          2
# Quinton de Kock      2
# Shubman Gill         2
# Avesh Khan           2
# Dinesh Karthik       2
# Hardik Pandya        2
# Rahul Tripathi       2
# Name: count, dtype: int64

# %%
sns.barplot(y=count.index,x=count.values , palette="mako")
plt.title("Player Of The Match Award")
# Out:
# Text(0.5, 1.0, 'Player Of The Match Award')

# %% [markdown]
# 2 Top Scorers

# %%
df.head(5)
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %%
high=df.groupby('top_scorer')['highscore'].sum().sort_values(ascending=False).head(2)
high
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# Name: highscore, dtype: int64

# %%
high.plot(kind='barh')
# Out:
# <Axes: ylabel='top_scorer'>

# %% [markdown]
# 10 Best Bowling Figure

# %%
df.head(3)
# Out:
#    match_id           date                               venue     team1  \
# 0         1  March 26,2022            Wankhede Stadium, Mumbai   Chennai
# 1         2  March 27,2022           Brabourne Stadium, Mumbai     Delhi
# 2         3  March 27,2022  Dr DY Patil Sports Academy, Mumbai  Banglore
#
#      team2  stage toss_winner toss_decision  first_ings_score  \
# 0  Kolkata  Group     Kolkata         Field               131
# 1   Mumbai  Group       Delhi         Field               177
# 2   Punjab  Group      Punjab         Field               205
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# 0                5                133                 4      Kolkata  Wickets
# 1                5                179                 6        Delhi  Wickets
# 2                2                208                 5       Punjab  Wickets
#
#    margin player_of_the_match      top_scorer  highscore    best_bowling  \
# ...

# %%
df['highest_wickets']=df['best_bowling_figure'].apply(lambda x:x.split('--')[0])  # extract wickets
df['highest_wickets']=df['highest_wickets'].astype(int)

top_bowler=df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowler
# Out:
# best_bowling
# Yuzvendra Chahal     17
# Jasprit Bumrah       11
# Kuldeep Yadav        11
# Rashid Khan          11
# Josh Hazlewood       10
# Kagiso Rabada        10
# Avesh Khan           10
# Umran Malik           9
# Wanindu Hasaranga     9
# T Natarajan           8
# Name: highest_wickets, dtype: int64

# %%
top_bowler.plot(kind='barh')
# Out:
# <Axes: ylabel='best_bowling'>

# %% [markdown]
# VENUE ANALYSIS

# %% [markdown]
# Most Matches Played By Venue

# %%
venue_count=df['venue'].value_counts()
venue_count
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
venue_count.plot(kind='barh')
# Out:
# <Axes: ylabel='venue'>

# %% [markdown]
# CUSTOM QUESTION AND INSIGHTS

# %% [markdown]
# Q Who Won The Highest Margin By Runs

# %%
df.head(3)
# Out:
#    match_id           date                               venue     team1  \
# 0         1  March 26,2022            Wankhede Stadium, Mumbai   Chennai
# 1         2  March 27,2022           Brabourne Stadium, Mumbai     Delhi
# 2         3  March 27,2022  Dr DY Patil Sports Academy, Mumbai  Banglore
#
#      team2  stage toss_winner toss_decision  first_ings_score  \
# 0  Kolkata  Group     Kolkata         Field               131
# 1   Mumbai  Group       Delhi         Field               177
# 2   Punjab  Group      Punjab         Field               205
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# 0                5  ...                 4       Kolkata  Wickets      6
# 1                5  ...                 6         Delhi  Wickets      4
# 2                2  ...                 5        Punjab  Wickets      5
#
#    player_of_the_match      top_scorer highscore    best_bowling  \
# ...

# %%
df[df['won_by']=='Runs'].sort_values(by='margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %% [markdown]
# Q  Which Player Had The Highest Individual Scores

# %%
df[df['highscore'] == df['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %% [markdown]
# Q Which Bowler Had The Best Bowling Figure

# %%
df[df['highest_wickets']==df['highest_wickets'].max()][['best_bowling','best_bowling']]
# Out:
#          best_bowling       best_bowling
# 29   Yuzvendra Chahal   Yuzvendra Chahal
# 39        Umran Malik        Umran Malik
# 53  Wanindu Hasaranga  Wanindu Hasaranga
# 55     Jasprit Bumrah     Jasprit Bumrah
